# %%
import pandas as pd
import numpy as np

# %%
# !ls
# Out:
# 'Basic Visualisation.ipynb'
#  Dashborad_hvplot.ipynb
# 'Data Analysis.ipynb'
#  Data_Extract_From_World_Development_Indicators.zip
#  world_dev_ind.csv

# %%
# !mv 5a8b8e3d-bf6d-4c76-8b5f-3cc2a11de4fc_Data.csv world_dev_ind.csv

# %%
df =pd.read_csv("world_dev_ind.csv")

# %%
df.head()
# Out:
#    Time Time Code Country Name Country Code  \
# 0  2010    YR2010    Argentina          ARG
# 1  2010    YR2010    Australia          AUS
# 2  2010    YR2010       Brazil          BRA
# 3  2010    YR2010        China          CHN
# 4  2010    YR2010       France          FRA
#
#   Adolescent fertility rate (births per 1,000 women ages 15-19) [SP.ADO.TFRT]  \
# 0                                            63.3154
# 1                                            14.2212
# 2                                            66.8926
# 3                                             7.3422
# 4                                              6.888
#
#   Agriculture, forestry, and fishing, value added (% of GDP) [NV.AGR.TOTL.ZS]  \
# 0                                   7.13216745078964
# 1                                   2.19756826525444
# 2                                   4.11575648758173
# 3                                   9.32517694051016
# 4                                   1.60402828863388
# ...

# %%
df.shape
# Out:
# (205, 59)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 59 columns):
#  #   Column                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                           --------------  -----
#  0   Time                                                                                             202 non-null    object
#  1   Time Code                                                                                        200 non-null    object
#  2   Country Name                                                                                     200 non-null    object
#  3   Country Code                                                                                     200 non-null    object
#  4   Adolescent fertility rate (births per 1,000 women ages 15-19) [SP.ADO.TFRT]                      200 non-null    object
# ...

# %%
qus = df.columns
qus=qus.drop(["Time",'Time Code','Country Name', 'Country Code'])

# %%
df.dropna(subset=['Time', 'Country Name'],inplace=True)
for i in qus:
    df[i].replace('..',np.nan,inplace=True)
    
qus= list(qus)
for i in qus:
    if df[i].isnull().sum() > 100:
        qus.remove(i)
df[qus].isnull().sum()
# Out:
# Adolescent fertility rate (births per 1,000 women ages 15-19) [SP.ADO.TFRT]                         20
# Agriculture, forestry, and fishing, value added (% of GDP) [NV.AGR.TOTL.ZS]                          2
# Births attended by skilled health staff (% of total) [SH.STA.BRTC.ZS]                              128
# CO2 emissions (metric tons per capita) [EN.ATM.CO2E.PC]                                             64
# Domestic credit provided by financial sector (% of GDP) [FS.AST.DOMS.GD.ZS]                        139
# Electric power consumption (kWh per capita) [EG.USE.ELEC.KH.PC]                                    100
# Energy use (kg of oil equivalent per capita) [EG.USE.PCAP.KG.OE]                                    87
# Exports of goods and services (% of GDP) [NE.EXP.GNFS.ZS]                                            1
# Fertility rate, total (births per woman) [SP.DYN.TFRT.IN]                                           20
# ...

# %%
for i in qus:
    df[i].fillna(method='ffill',inplace=True)
    df[i].fillna(method='bfill',inplace=True)
    df[i].astype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 0 to 199
# Data columns (total 59 columns):
#  #   Column                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                           --------------  -----
#  0   Time                                                                                             200 non-null    object
#  1   Time Code                                                                                        200 non-null    object
#  2   Country Name                                                                                     200 non-null    object
#  3   Country Code                                                                                     200 non-null    object
#  4   Adolescent fertility rate (births per 1,000 women ages 15-19) [SP.ADO.TFRT]                      200 non-null    object
# ...
